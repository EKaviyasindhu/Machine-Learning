# %%
#importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset = dataset.astype(int)

# %%
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
#from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error','absolute_error','friedman_mse',], 'max_features': ['sqrt','log2', None], 'n_estimators':[10,100]}

grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)

# fitting the model for grid search
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.186189      0.059485         0.017666        0.006536
# 1        0.629653      0.032154         0.024740        0.002131
# 2        0.061646      0.003178         0.005787        0.002394
# 3        0.592742      0.038559         0.024939        0.003837
# 4        0.083394      0.013378         0.011572        0.011695
# 5        0.742375      0.035569         0.024142        0.003858
# 6        0.213873      0.014937         0.005387        0.001955
# 7        1.834492      0.011752         0.027134        0.010602
# 8        0.205094      0.023594         0.004390        0.000489
# 9        1.822521      0.034746         0.022945        0.001995
# 10       0.299463      0.012719         0.007383        0.003919
# 11       3.838368      0.730698         0.037326        0.003042
# 12       0.090152      0.006440         0.006808        0.001415
# 13       1.016516      0.020038         0.037879        0.005871
# 14       0.105774      0.012351         0.007513        0.001161
# 15       1.066398      0.061463         0.036508        0.005353
# 16       0.126103      0.032669         0.007568        0.000774
# 17       1.024752      0.054782         0.033458        0.001860
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 10
# 1    squared_error               sqrt                100
# 2    squared_error               log2                 10
# 3    squared_error               log2                100
# 4    squared_error               None                 10
# 5    squared_error               None                100
# 6   absolute_error               sqrt                 10
# 7   absolute_error               sqrt                100
# 8   absolute_error               log2                 10
# 9   absolute_error               log2                100
# 10  absolute_error               None                 10
# 11  absolute_error               None                100
# 12    friedman_mse               sqrt                 10
# 13    friedman_mse               sqrt                100
# 14    friedman_mse               log2                 10
# 15    friedman_mse               log2                100
# 16    friedman_mse               None                 10
# 17    friedman_mse               None                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.840695
# 1   {'criterion': 'squared_error', 'max_features':...           0.852383
# 2   {'criterion': 'squared_error', 'max_features':...           0.826797
# 3   {'criterion': 'squared_error', 'max_features':...           0.852447
# 4   {'criterion': 'squared_error', 'max_features':...           0.835229
# 5   {'criterion': 'squared_error', 'max_features':...           0.843674
# 6   {'criterion': 'absolute_error', 'max_features'...           0.832716
# 7   {'criterion': 'absolute_error', 'max_features'...           0.853012
# 8   {'criterion': 'absolute_error', 'max_features'...           0.855187
# 9   {'criterion': 'absolute_error', 'max_features'...           0.856040
# 10  {'criterion': 'absolute_error', 'max_features'...           0.813860
# 11  {'criterion': 'absolute_error', 'max_features'...           0.831798
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.843318
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.853048
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.835377
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.856231
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.843433
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.840601
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.771343           0.824109           0.822802
# 1            0.772969           0.850790           0.822489
# 2            0.757889           0.845734           0.808226
# 3            0.766921           0.852632           0.823849
# 4            0.749750           0.843545           0.796979
# 5            0.767477           0.853797           0.810197
# 6            0.758697           0.845624           0.805208
# 7            0.775196           0.857322           0.821993
# 8            0.762446           0.839276           0.819491
# 9            0.776053           0.853635           0.827356
# 10           0.761855           0.837748           0.815392
# 11           0.758966           0.853045           0.818263
# 12           0.751893           0.840166           0.803927
# 13           0.773122           0.858163           0.826195
# 14           0.748833           0.841409           0.804710
# 15           0.777161           0.856445           0.824017
# 16           0.746895           0.846357           0.800701
# 17           0.769630           0.856591           0.808293
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.824185         0.816627        0.023584               11
# 1            0.836702         0.827066        0.029134                5
# 2            0.835074         0.814744        0.030964               12
# 3            0.835968         0.826363        0.031630                6
# 4            0.820259         0.809152        0.033654               17
# 5            0.825548         0.820139        0.030293                9
# 6            0.828580         0.814165        0.030655               13
# 7            0.837370         0.828979        0.029640                4
# 8            0.841256         0.823531        0.032594                7
# 9            0.836403         0.829897        0.028965                2
# 10           0.826276         0.811026        0.026044               15
# 11           0.837619         0.819938        0.032465               10
# 12           0.817488         0.811358        0.033107               14
# 13           0.840620         0.830230        0.030615                1
# 14           0.812643         0.808595        0.032854               18
# 15           0.832427         0.829256        0.029046                3
# 16           0.815443         0.810566        0.036156               16
# 17           0.833879         0.821799        0.030377                8

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 33
# BMI: 3
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
#change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[9515.59]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
